# %%
# Import to be able to import python package from src
import sys
sys.path.insert(0, '../')

# %%
from src.pyregbl.main import client

# %%
client.get("1522978_0").attributes()
# Out:
# {'egid': '1522978',
#  'strname_deinr': 'Avenue du Général-Guisan 36',
#  'plz_plz6': '1700/170000',
#  'ggdename': 'Fribourg',
#  'ggdenr': 2196,
#  'gexpdat': '06.07.2024',
#  'gdekt': 'FR',
#  'egrid': 'CH753210919473',
#  'lgbkr': 0,
#  'lparz': '6275',
#  'lparzsx': None,
#  'ltyp': None,
#  'gebnr': '',
#  'gbez': '',
#  'gkode': 2577841.626,
#  'gkodn': 1184475.436,
#  'gksce': 901,
#  'gstat': 1004,
#  'gkat': 1020,
#  'gklas': 1122,
#  'gbauj': None,
#  'gbaum': None,
#  'gbaup': 8014,
#  'gabbj': None,
#  'garea': 402,
#  'gvol': None,
#  'gvolnorm': None,
#  'gvolsce': None,
#  'gastw': 9,
#  'ganzwhg': 39,
#  'gazzi': None,
#  'gschutzr': None,
#  'gebf': None,
#  'gwaerzh1': 'Chaudière (générique) pour plusieurs bâtiments',
#  'genh1': 'Mazout',
#  'gwaersceh1': 'Selon contrôle des installations de chauffage',
#  'gwaerdath1': '31.12.2014',
#  'gwaerzh2': None,
#  'genh2': None,
#  'gwaersceh2': None,
#  'gwaerdath2': '-',
#  'gwaerzw1': 'Chaudière (générique)',
# ...
